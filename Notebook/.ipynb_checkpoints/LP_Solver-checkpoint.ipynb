# %% [markdown]
# # Ricci curvature for graphs

# %% [markdown]
# This program includes a LP solver for EMD problem. Computes Ric(u,v) and Ric(u)
#
# Input: Undirected Unweighted graph G
#
# Output: Ric (u,v), Ric(u)

# %% [markdown]
# # Preamble

# %%
INPUT_PATH = "../data/control11.txt"

# %%
import matplotlib.pyplot as plt
import networkx as nx
#import networkit as nk
import cvxpy as cp
import numpy as np
from numpy import genfromtxt
import ot
import pytest

# %% [markdown]
# # Load Input

# %%
# y = np.loadtxt(INPUT_PATH, delimiter=",")
# print(y)
# np.array2string(x, precision=2, separator=',',
# ...                       suppress_small=True)

# %%
import re, ast
matrix = open(INPUT_PATH, 'r').read()
matrix = re.sub('\s+', ',', matrix)
A = np.array(ast.literal_eval(matrix))
A
# G = nx.from_numpy_matrix(A)

# # Python code to demonstrate converting  
# # string representation of list to list 
# # using strip and split 
  
# # initializing string representation of a list 
# ini_list = matrix
  
# # printing initialized string of list and its type 
# # print ("initial string", ini_list) 
# print (type(ini_list)) 
  
# # Converting string to list 
# res = ini_list.strip('][').split(', ') 
  
# # printing final result and its type 
# print ("final list", res) 
# print (type(res))
# Out:
# array([[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          2.56648704e-04, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 2.71085032e-01, ...,
#          0.00000000e+00, 2.34863707e-03, 0.00000000e+00],
#         [0.00000000e+00, 2.71085032e-01, 0.00000000e+00, ...,
#          1.30102257e-02, 9.14574755e-02, 0.00000000e+00],
#         ...,
#         [2.56648704e-04, 0.00000000e+00, 1.30102257e-02, ...,
#          0.00000000e+00, 5.14307173e-02, 3.70976084e-02],
#         [0.00000000e+00, 2.34863707e-03, 9.14574755e-02, ...,
#          5.14307173e-02, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          3.70976084e-02, 0.00000000e+00, 0.00000000e+00]]])

# %%
G = nx.karate_club_graph()

# %%
n = G.number_of_nodes()
m = G.number_of_edges()

# %%
 nx.draw(G, with_labels=True, font_weight='bold')

# %% [markdown]
# # 1. Ricci curvature for an edge {u, v} (denoted by Ric(u, v))

# %%
def get_weights(u):
    """return a list of weights for neighbors of node u From the point of view of node u """
    w = 1 / (1 + G.degree(u))
    length = G.degree(u) + 1
    return [w] * length
    
def get_distances(u, v):
    """distnace of node x_i and y_j for each pair neighbors of u and v """
    distances = [[nx.shortest_path_length(G,i,j) for j in list(G.neighbors(v))+[v]] for i in list(G.neighbors(u))+[u]]
    return distances

# %%
def EMD(u, v):
    """returns erth mover distance for the give pair of nodes -- where u and v are adjacent"""
    # a,b are 1D histograms (sum to 1 and positive)
    a = get_weights(u)
    b = get_weights(v)
    # M is the ground cost matrix
    M = get_distances(u, v)
    T = ot.emd(a,b,M) # exact linear programb
    W = ot.emd2(a,b,M) # Wasserstein distance / EMD value
    return  W

# %%
def Ric(u, v):
    return 1-EMD(u,v)

# %%
get_weights(24)
# Out:
# [0.25, 0.25, 0.25, 0.25]

# %%
get_weights(25)
# Out:
# [0.25, 0.25, 0.25, 0.25]

# %%
get_distances(24,25)
# Out:
# [[1, 1, 1, 0], [1, 1, 2, 2], [2, 1, 0, 1], [2, 0, 1, 1]]

# %%
ot.emd(get_weights(24),get_weights(25),get_distances(24,25))
# Out:
# array([[0.  , 0.  , 0.  , 0.25],
#        [0.25, 0.  , 0.  , 0.  ],
#        [0.  , 0.  , 0.25, 0.  ],
#        [0.  , 0.25, 0.  , 0.  ]])

# %%
print(EMD(24,25))
# Out:
# 0.25

# %%
print(Ric(24,25))
# Out:
# 0.75

# %% [markdown]
# # 2. Ricci curvature for a node u (denoted by Ric(u))

# %%
def Ricci(u):
    sum = 0
    for x in G.neighbors(u):
        sum += Ric(u,x)
    return sum/G.degree(u)

# %%
Ricci(24)
# Out:
# 0.35238095238095246

# %% [markdown]
# # 3. Some simple observations for Ric(u, v)

# %%
from numpy import array
def TV(u,v):
    Nbr_u = sorted(nx.neighbors(G, u))
    Nbr_v = sorted(nx.neighbors(G, v))
    l = sorted(nx.common_neighbors(G, u, v))
    k = [i for i in Nbr_u  if i not in l] 
    m = [i for i in Nbr_v  if i not in l] 
    u_vec = [1/(nx.degree(G,u)+1) for i in Nbr_u] + [1/(nx.degree(G,u)+1)] +[0 for i in m] + [1/(nx.degree(G,u)+1)]
    v_vec = [0 for i in k] + [1/(nx.degree(G,v)+1) for i in Nbr_v] + [1/(nx.degree(G,v)+1)] + [1/(nx.degree(G,v)+1)]
    tv_vec = np.array(u_vec) - np.array(v_vec) 
    tv = 0
    for x in tv_vec:
        tv = tv + (1/2) * x 
    return tv

# %%
def TV2(u,v):
    Nbr_u = sorted(nx.neighbors(G, u))
    Nbr_v = sorted(nx.neighbors(G, v))
    l = sorted(nx.common_neighbors(G, u, v))
    k = [i for i in Nbr_u  if i not in l] 
    m = [i for i in Nbr_v  if i not in l] 
    tv = ((len(k) + len(l))/2 + 1) / (nx.degree(G,u) + 1) + ((len(m) - len(l))/2 - 1) / (nx.degree(G,v) + 1)
    return tv

# %%
 sorted(nx.neighbors(G, 24))
# Out:
# [25, 27, 31]

# %%
sorted(nx.neighbors(G, 25))
# Out:
# [23, 24, 31]

# %%
sorted(nx.common_neighbors(G, 24, 25))
# Out:
# [31]

# %%
TV(25,24)
# Out:
# 0.0

# %%
TV2(25,24)
# Out:
# 0.5

# %%
Ric(24,25)
# Out:
# 0.75
